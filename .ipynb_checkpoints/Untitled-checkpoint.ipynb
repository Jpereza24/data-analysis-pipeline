# %%
import pandas as pd
import datetime
import re

# %%
df = pd.read_csv('../data-analysis-pipeline/results.csv')
df
# Out:
#              date     home_team   away_team  home_score  away_score  \
# 0      1872-11-30      Scotland     England           0           0
# 1      1873-03-08       England    Scotland           4           2
# 2      1874-03-07      Scotland     England           2           1
# 3      1875-03-06       England    Scotland           2           2
# 4      1876-03-04      Scotland     England           3           0
# ...           ...           ...         ...         ...         ...
# 41238  2019-10-20       Lesotho    Zimbabwe           0           0
# 41239  2019-10-20        Guinea     Senegal           1           0
# 41240  2019-10-20          Mali  Mauritania           2           0
# 41241  2019-10-20  Burkina Faso       Ghana           0           0
# 41242  2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# ...

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date          datetime64[ns]
# home_team             object
# away_team             object
# home_score             int64
# away_score             int64
# tournament            object
# city                  object
# country               object
# neutral                 bool
# dtype: object

# %%
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df = df.loc[(df['year'] > 1990)]

# %%
coleliminar = ['date','city','country', 'neutral', 'day', 'month']
df = df.drop(coleliminar, axis=1)

# %%
def tournament(e):
    listtourn = ['CONCACAF Nations League', 'Gold Cup qualification', 'Oceania Nations Cup', 'Friendly', 'African Cup of Nations qualification', 'UEFA Euro', 'African Nations Championship qualifying', 'UEFA Nations League', 'African Cup of Nations', 'Copa América qualification', 'Gold Cup', 'FIFA World Cup', 'Oceania Nations Cup qualification', 'CONCACAF Nations League qualifying', 'Confederations Cup', 'UEFA Euro qualification', 'Copa América', 'FIFA World Cup qualification']
    if e in listtourn:
        return e
    else:
        return 'No vale'

df['tournament'] = df['tournament'].apply(tournament)

# %%
df = df.loc[(df['tournament']!= 'No vale')]

# %%
df
# Out:
#           home_team    away_team  home_score  away_score  \
# 16308  Burkina Faso         Mali           2           0
# 16309  Burkina Faso        Niger           2           2
# 16311  Burkina Faso      Nigeria           1           1
# 16312         Ghana        Benin           4           0
# 16313       Morocco  Ivory Coast           3           1
# ...             ...          ...         ...         ...
# 41238       Lesotho     Zimbabwe           0           0
# 41239        Guinea      Senegal           1           0
# 41240          Mali   Mauritania           2           0
# 41241  Burkina Faso        Ghana           0           0
# 41242   Ivory Coast        Niger           1           0
#
#                                     tournament  year
# 16308                                 Friendly  1991
# 16309                                 Friendly  1991
# 16311     African Cup of Nations qualification  1991
# 16312     African Cup of Nations qualification  1991
# ...

# %%
def points1(row1,row2):
    row = 0
    if row1 > row2:
        row +=3
    elif row1 == row2:
        row +=1
    elif row1 < row2:
        row = 0
    return row

# %%
def points(value1,value2):
    value = 0
    for index, row in pd.DataFrame.iterrows():
        if value1 > value2:
            value +=3
        elif value1 == value2:
            value +=1
        elif value1 < value2:
            value = 0
    return index, value

# %%
df[index,'local_points'] = df.apply(points(df['home_score'], df['away_score']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-6f4bb9deaf8b> in <module>
# ----> 1 df[index,'local_points'] = df.apply(points(df['home_score'], df['away_score']))
#
# <ipython-input-161-2d392f728945> in points(value1, value2)
#       1 def points(value1,value2):
#       2     value = 0
# ----> 3     for index, row in pd.DataFrame.iterrows():
#       4         if value1 > value2:
#       5             value +=3
#
# TypeError: iterrows() missing 1 required positional argument: 'self'

# %%
series = pd.DataFrame(df[['home_score', 'away_score']])

# %%
series
# Out:
#        home_score  away_score
# 16308           2           0
# 16309           2           2
# 16310           4           0
# 16311           1           1
# 16312           4           0
# ...           ...         ...
# 41238           0           0
# 41239           1           0
# 41240           2           0
# 41241           0           0
# 41242           1           0
#
# [24935 rows x 2 columns]

# %%
for index, row in series.iterrows():
    series.loc[index,"local_points"] = points(row['home_score'], row['away_score'])

# %%
for index, row in series.iterrows():
    series.loc[index,"away_points"] = points(row['away_score'], row['home_score'])

# %%
series
# Out:
#        home_score  away_score  local_points  away_points
# 16308           2           0           3.0          0.0
# 16309           2           2           1.0          1.0
# 16310           4           0           3.0          0.0
# 16311           1           1           1.0          1.0
# 16312           4           0           3.0          0.0
# ...           ...         ...           ...          ...
# 41238           0           0           1.0          1.0
# 41239           1           0           3.0          0.0
# 41240           2           0           3.0          0.0
# 41241           0           0           1.0          1.0
# 41242           1           0           3.0          0.0
#
# [24935 rows x 4 columns]

# %%
series['local points'] = series.apply(points(series['home_score'], series['away_score']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-9daad88977f9> in <module>
# ----> 1 series['puntos'] = series.apply(points(series['home_score'], series['away_score']))
#
# <ipython-input-89-bb11a51b3f3f> in points(row1, row2)
#       1 def points(row1,row2):
#       2     row = 0
# ----> 3     if row1 > row2:
#       4         row +=3
#       5     if row1 == row2:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
